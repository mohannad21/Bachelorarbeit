# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn import datasets,svm
from matplotlib import style
style.use("ggplot")
from collections import Counter
from mpl_toolkits.mplot3d import Axes3D
from pylab import *
from sklearn import svm
from scipy.spatial.distance import cdist
from sklearn.metrics import confusion_matrix
import matplotlib.font_manager
import pylab as pl

# %%
#file = 'CW PUMP 1B CURRENT.csv'
#file = 'ID FAN 1B MTR OBRG TEMP.csv'
file = 'temperator.csv'
#file = 'pressure2.csv'
#file = '9-1-2008 to 9-1-2009 Trend.csv'

if (file == 'CW PUMP 1B CURRENT.csv'):
    outlierRange = []
    outlierRangeDel = []

elif (file == 'ID FAN 1B MTR OBRG TEMP.csv'):
    outlierRange = []
    outlierRangeDel = []

elif (file == 'temperator.csv'):
    outlierRange = [90, 10]
    outlierRangeDel = [100, -10]
    outlierRangePosDel = [] 
elif (file == '9-1-2008 to 9-1-2009 Trend.csv'):
    outlierRange = []
    outlierRangeDel = []
elif (file == 'pressure.xlsx'):
    outlierRange = [90, 10]
    outlierRangeDel = [100, -10]
    outlierRangePosDel = []

# %%
rowDates = []
rowValues = []
counter = 0

dataDF = pd.read_csv(file,  header=None)  

for index, row in dataDF.iterrows():
    rowValue = row[1]
    rowDate = row[0]
    try:
        float(rowValue)
        pd.to_datetime(rowDate)
        rowValues.append(float(rowValue))
        rowDates.append(pd.to_datetime(rowDate))                    
    except:
        counter += 1
        continue
    if index == 20000:
        break

print('values :',len(rowValues))
print('dates :',len(rowDates))
print('invalid :',counter)
# Out:
# values : 19994
# dates : 19994
# invalid : 7

# %%
def createAnomalyList(values, interval):
    counterNew = 0
    outlier = []
    for v in values:
        if (v < interval[0] or v > interval[1]):
            #print(v)
            outlier.append(1)
            counterNew = counterNew + 1
        else:
            outlier.append(0)
    print("anomalie :", counterNew)
    return outlier

# %%
def calculateDelta(values, dates):
    deltaDates = dates.copy()
    del deltaDates[0]
    delta = []
    posDelta = []

    for idx in range(1, len(values)):
        x = values[idx] - values[idx - 1]
        delta.append(x)
        if(x < 0):
            posDelta.append(-1*x)
        else:
            posDelta.append(x)
            
    print("delta Values: ", len(delta))
    print("pos delta Values: ", len(posDelta))
    print("delta Dates: ", len(deltaDates))

    return delta, posDelta, deltaDates

# %%
def plotTheclusteredData(dates, values, labels, titel):
    fig, (ax1) = plt.subplots(1, figsize=(14,6))
    ax1.scatter(dates, values , c=labels.astype(np.float))
    ax1.set_xlabel("$Time$")
    ax1.set_ylabel("$Value$")
    ax1.set_title(titel)
    plt.show()

# %%
def plotTheElbow(K, distortions):
    plt.plot(K, distortions, 'bx-')
    plt.xlabel('k')
    plt.ylabel('Distortion')
    plt.title('The Elbow Method showing the optimal k')
    plt.show()

# %%
def plotTheDataWithoutClusters(x, predicted, rowValues, rowDates, titel):
    print("without cluster : " , x )
    counterProCluster = 0
    clusterVal = []
    clusterDate = []
    predictedNew = []

    for i in range(len(predicted)):
        if(predicted[i] != x):
            counterProCluster = counterProCluster + 1
            clusterVal.append(rowValues[i])
            clusterDate.append(rowDates[i])
            predictedNew.append(predicted[i])
        else:
            continue

    ax = plt.gca()
    ax.scatter(clusterDate, clusterVal, c = predictedNew)
    plt.title(titel)
    plt.show()

# %%
def calculatePrecision(cm):
    tp = cm[0][0]
    tn = cm[1][1]
    fp = cm[0][1]
    fn = cm[1][0]
    precision = tp / (tp + fp)
    return precision

# %%
def calculateRecall(cm):
    tp = cm[0][0]
    tn = cm[1][1]
    fp = cm[0][1]
    fn = cm[1][0]
    recall = tp / (tp + fn)
    return recall

# %%
outlierRange = [5, 100]
outlierRangeDel = [0, 25]

outlier = createAnomalyList(rowValues, outlierRange)
deltaValues, posDeltaValues, deltaDates = calculateDelta(rowValues, rowDates)
outlierDelta = createAnomalyList(deltaValues, outlierRangeDel)
outlierPosDelta = createAnomalyList(posDeltaValues, outlierRangeDel)
# Out:
# anomalie : 9
# delta Values:  19993
# pos delta Values:  19993
# delta Dates:  19993
# anomalie : 10090
# anomalie : 18

# %%
fig, (ax1) = plt.subplots(1, figsize=(14,6))

ax1.scatter(rowDates, rowValues, c="green")
#ax1.scatter(deltaDates, deltaValues, c="green")
#ax1.scatter(deltaDates, posDeltaValues, c="green")


ax1.set_xlabel("$Time$")
ax1.set_ylabel("$Value$")

ax1.set_title("$K-Means original$")
plt.show()

# %%
values = np.asarray(posDeltaValues).reshape(-1, 1)
dates = np.asarray(deltaDates)
outlierList = outlierPosDelta
datesDisplay = rowDates.copy()
valuesDisplay = rowValues.copy()
del datesDisplay[0]
del valuesDisplay[0]

nuList = []
preList = []

x = 1
while(x != 0):
    if(x > 0):
        print("nu = ", x)
        nuList.append(x)
        #clf = svm.OneClassSVM(nu=0.0001, kernel="rbf", gamma=0.0001)
        clf = svm.OneClassSVM(nu=x)
        clf.fit(values)
        predicted = clf.predict(values)

        counterFirst = 0
        counterSec = 0
        counts= []
        predictedNew = []
        for i in predicted:
            if i == 1: 
                predictedNew.append(0)
                counterFirst = counterFirst + 1
            else:
                predictedNew.append(1)
                counterSec = counterSec + 1

        cm = confusion_matrix(outlierList, predictedNew)
        print ("num of samples in the first class : ", counterFirst, "   percent: ", counterFirst / len(values))
        print ("num of samples in the secon class : ", counterSec, "     percent: ", counterFirst / len(values))
        print(cm)
        precision = calculatePrecision(cm)
        recall = calculateRecall(cm)
        print("precision : ", precision)
        print("recall    : " ,recall)
        preList.append(precision)

        #plotTheclusteredData(dates, values, predicted, titel= "$OneClassSVM$")
        x = x-0.1
        print("-----------------")
    else:
        print("nu = 0")
        break
plotTheElbow(nuList ,preList)
# Out:
# nu =  1
# num of samples in the first class :  0    percent:  0.0
# num of samples in the secon class :  19993      percent:  0.0
# [[    0 19975]
#  [    0    18]]
# precision :  0.0
# recall    :  nan
# -----------------
# nu =  0.9
# num of samples in the first class :  2007    percent:  0.10038513479717902
# num of samples in the secon class :  17986      percent:  0.10038513479717902
# [[ 2007 17968]
#  [    0    18]]
# precision :  0.100475594493
# recall    :  1.0
# -----------------
# nu =  0.8
# num of samples in the first class :  3979    percent:  0.19901965687990797
# num of samples in the secon class :  16014      percent:  0.19901965687990797
# [[ 3979 15996]
#  [    0    18]]
# precision :  0.199198998748
# recall    :  1.0
# -----------------
# nu =  0.7000000000000001
# num of samples in the first class :  6023    percent:  0.30125543940379135
# num of samples in the secon class :  13970      percent:  0.30125543940379135
# [[ 6023 13952]
#  [    0    18]]
# precision :  0.301526908636
# recall    :  1.0
# -----------------
# nu =  0.6000000000000001
# num of samples in the first class :  7982    percent:  0.3992397339068674
# num of samples in the secon class :  12011      percent:  0.3992397339068674
# [[ 7982 11993]
#  [    0    18]]
# precision :  0.399599499374
# recall    :  1.0
# -----------------
# nu =  0.5000000000000001
# num of samples in the first class :  9971    percent:  0.49872455359375784
# num of samples in the secon class :  10022      percent:  0.49872455359375784
# [[ 9971 10004]
#  [    0    18]]
# precision :  0.499173967459
# recall    :  1.0
# -----------------
# nu =  0.40000000000000013
# num of samples in the first class :  11982    percent:  0.5993097584154454
# num of samples in the secon class :  8011      percent:  0.5993097584154454
# [[11982  7993]
#  [    0    18]]
# precision :  0.599849812265
# recall    :  1.0
# -----------------
# nu =  0.30000000000000016
# num of samples in the first class :  13985    percent:  0.6994948231881158
# num of samples in the secon class :  6008      percent:  0.6994948231881158
# [[13985  5990]
#  [    0    18]]
# precision :  0.700125156446
# recall    :  1.0
# -----------------
# nu =  0.20000000000000015
# num of samples in the first class :  15997    percent:  0.8001300455159306
# num of samples in the secon class :  3996      percent:  0.8001300455159306
# [[15997  3978]
#  [    0    18]]
# precision :  0.80085106383
# recall    :  1.0
# -----------------
# nu =  0.10000000000000014
# num of samples in the first class :  17996    percent:  0.9001150402640924
# num of samples in the secon class :  1997      percent:  0.9001150402640924
# [[17996  1979]
#  [    0    18]]
# precision :  0.900926157697
# recall    :  1.0
# -----------------
# nu =  1.3877787807814457e-16
# num of samples in the first class :  0    percent:  0.0
# num of samples in the secon class :  19993      percent:  0.0
# [[    0 19975]
#  [    0    18]]
# precision :  0.0
# recall    :  nan
# -----------------
# nu = 0

# %%
values = np.asarray(posDeltaValues).reshape(-1, 1)
dates = np.asarray(deltaDates)
outlierList = outlierPosDelta
datesDisplay = rowDates.copy()
valuesDisplay = rowValues.copy()
del datesDisplay[0]
del valuesDisplay[0]

nuList = []
preList = []

x = 0.1
while(x != 0):
    if(x > 0):
        print("nu = ", x)
        nuList.append(x)
        #clf = svm.OneClassSVM(nu=0.0001, kernel="rbf", gamma=0.0001)
        clf = svm.OneClassSVM(nu=x)
        clf.fit(values)
        predicted = clf.predict(values)

        counterFirst = 0
        counterSec = 0
        counts= []
        predictedNew = []
        for i in predicted:
            if i == 1: 
                predictedNew.append(0)
                counterFirst = counterFirst + 1
            else:
                predictedNew.append(1)
                counterSec = counterSec + 1

        cm = confusion_matrix(outlierList, predictedNew)
        print ("num of samples in the first class : ", counterFirst, "   percent: ", counterFirst / len(values))
        print ("num of samples in the secon class : ", counterSec, "     percent: ", counterFirst / len(values))
        print(cm)
        precision = calculatePrecision(cm)
        recall = calculateRecall(cm)
        print("precision : ", precision)
        print("recall    : " ,recall)
        preList.append(precision)

        #plotTheclusteredData(dates, values, predicted, titel= "$OneClassSVM$")
        x = x-0.01
        print("-----------------")
    else:
        print("nu = 0")
        break

plotTheElbow(nuList ,preList)
# Out:
# nu =  0.1
# num of samples in the first class :  17996    percent:  0.9001150402640924
# num of samples in the secon class :  1997      percent:  0.9001150402640924
# [[17996  1979]
#  [    0    18]]
# precision :  0.900926157697
# recall    :  1.0
# -----------------
# nu =  0.09000000000000001
# num of samples in the first class :  18194    percent:  0.910018506477267
# num of samples in the secon class :  1799      percent:  0.910018506477267
# [[18194  1781]
#  [    0    18]]
# precision :  0.910838548185
# recall    :  1.0
# -----------------
# nu =  0.08000000000000002
# num of samples in the first class :  18376    percent:  0.9191216925924074
# num of samples in the secon class :  1617      percent:  0.9191216925924074
# [[18376  1599]
#  [    0    18]]
# precision :  0.919949937422
# recall    :  1.0
# -----------------
# nu =  0.07000000000000002
# num of samples in the first class :  18584    percent:  0.9295253338668534
# num of samples in the secon class :  1409      percent:  0.9295253338668534
# [[18584  1391]
#  [    0    18]]
# precision :  0.930362953692
# recall    :  1.0
# -----------------
# nu =  0.06000000000000002
# num of samples in the first class :  18773    percent:  0.9389786425248837
# num of samples in the secon class :  1220      percent:  0.9389786425248837
# [[18773  1202]
#  [    0    18]]
# precision :  0.939824780976
# recall    :  1.0
# -----------------
# nu =  0.05000000000000002
# num of samples in the first class :  18995    percent:  0.9500825288851098
# num of samples in the secon class :  998      percent:  0.9500825288851098
# [[18995   980]
#  [    0    18]]
# precision :  0.950938673342
# recall    :  1.0
# -----------------
# nu =  0.040000000000000015
# num of samples in the first class :  19180    percent:  0.9593357675186315
# num of samples in the secon class :  813      percent:  0.9593357675186315
# [[19180   795]
#  [    0    18]]
# precision :  0.960200250313
# recall    :  1.0
# -----------------
# nu =  0.030000000000000013
# num of samples in the first class :  19383    percent:  0.9694893212624418
# num of samples in the secon class :  610      percent:  0.9694893212624418
# [[19383   592]
#  [    0    18]]
# precision :  0.970362953692
# recall    :  1.0
# -----------------
# nu =  0.02000000000000001
# num of samples in the first class :  19567    percent:  0.9786925423898365
# num of samples in the secon class :  426      percent:  0.9786925423898365
# [[19567   408]
#  [    0    18]]
# precision :  0.979574468085
# recall    :  1.0
# -----------------
# nu =  0.01000000000000001
# num of samples in the first class :  19769    percent:  0.9887960786275196
# num of samples in the secon class :  224      percent:  0.9887960786275196
# [[19769   206]
#  [    0    18]]
# precision :  0.989687108886
# recall    :  1.0
# -----------------
# nu =  1.0408340855860843e-17
# num of samples in the first class :  0    percent:  0.0
# num of samples in the secon class :  19993      percent:  0.0
# [[    0 19975]
#  [    0    18]]
# precision :  0.0
# recall    :  nan
# -----------------
# nu = 0

# %%
values = np.asarray(posDeltaValues).reshape(-1, 1)
dates = np.asarray(deltaDates)
outlierList = outlierPosDelta
datesDisplay = rowDates.copy()
valuesDisplay = rowValues.copy()
del datesDisplay[0]
del valuesDisplay[0]

nuList = []
preList = []

x = 0.01
while(x != 0):
    if(x > 0):
        print("nu = ", x)
        nuList.append(x)
        #clf = svm.OneClassSVM(nu=0.0001, kernel="rbf", gamma=0.0001)
        clf = svm.OneClassSVM(nu=x)
        clf.fit(values)
        predicted = clf.predict(values)

        counterFirst = 0
        counterSec = 0
        counts= []
        predictedNew = []
        for i in predicted:
            if i == 1: 
                predictedNew.append(0)
                counterFirst = counterFirst + 1
            else:
                predictedNew.append(1)
                counterSec = counterSec + 1

        cm = confusion_matrix(outlierList, predictedNew)
        print ("num of samples in the first class : ", counterFirst, "   percent: ", counterFirst / len(values))
        print ("num of samples in the secon class : ", counterSec, "     percent: ", counterFirst / len(values))
        print(cm)
        precision = calculatePrecision(cm)
        recall = calculateRecall(cm)
        preList.append(precision)

        print("precision : ", precision)
        print("recall    : " ,recall)
        #plotTheclusteredData(dates, values, predicted, titel= "$OneClassSVM$")
        x = x-0.001
        print("-----------------")
    else:
        print("nu = 0")
        break
plotTheElbow(nuList ,preList)
# Out:
# nu =  0.01
# num of samples in the first class :  19769    percent:  0.9887960786275196
# num of samples in the secon class :  224      percent:  0.9887960786275196
# [[19769   206]
#  [    0    18]]
# precision :  0.989687108886
# recall    :  1.0
# -----------------
# nu =  0.009000000000000001
# num of samples in the first class :  19793    percent:  0.9899964987745711
# num of samples in the secon class :  200      percent:  0.9899964987745711
# [[19793   182]
#  [    0    18]]
# precision :  0.990888610763
# recall    :  1.0
# -----------------
# nu =  0.008
# num of samples in the first class :  19861    percent:  0.993397689191217
# num of samples in the secon class :  132      percent:  0.993397689191217
# [[19861   114]
#  [    0    18]]
# precision :  0.994292866083
# recall    :  1.0
# -----------------
# nu =  0.007
# num of samples in the first class :  19835    percent:  0.9920972340319112
# num of samples in the secon class :  158      percent:  0.9920972340319112
# [[19835   140]
#  [    0    18]]
# precision :  0.992991239049
# recall    :  1.0
# -----------------
# nu =  0.006
# num of samples in the first class :  19861    percent:  0.993397689191217
# num of samples in the secon class :  132      percent:  0.993397689191217
# [[19861   114]
#  [    0    18]]
# precision :  0.994292866083
# recall    :  1.0
# -----------------
# nu =  0.005
# num of samples in the first class :  19888    percent:  0.9947481618566498
# num of samples in the secon class :  105      percent:  0.9947481618566498
# [[19888    87]
#  [    0    18]]
# precision :  0.995644555695
# recall    :  1.0
# -----------------
# nu =  0.004
# num of samples in the first class :  19928    percent:  0.9967488621017356
# num of samples in the secon class :  65      percent:  0.9967488621017356
# [[19928    47]
#  [    0    18]]
# precision :  0.997647058824
# recall    :  1.0
# -----------------
# nu =  0.003
# num of samples in the first class :  19948    percent:  0.9977492122242785
# num of samples in the secon class :  45      percent:  0.9977492122242785
# [[19948    27]
#  [    0    18]]
# precision :  0.998648310388
# recall    :  1.0
# -----------------
# nu =  0.002
# num of samples in the first class :  19961    percent:  0.9983994398039314
# num of samples in the secon class :  32      percent:  0.9983994398039314
# [[19961    14]
#  [    0    18]]
# precision :  0.999299123905
# recall    :  1.0
# -----------------
# nu =  0.001
# num of samples in the first class :  19857    percent:  0.9931976191667083
# num of samples in the secon class :  136      percent:  0.9931976191667083
# [[19846   129]
#  [   11     7]]
# precision :  0.993541927409
# recall    :  0.99944603918
# -----------------

# %%
values = np.asarray(posDeltaValues).reshape(-1, 1)
dates = np.asarray(deltaDates)
outlierList = outlierPosDelta
datesDisplay = rowDates.copy()
valuesDisplay = rowValues.copy()
del datesDisplay[0]
del valuesDisplay[0]

nuList = []
preList = []

x = 0.002
while(x != 0):
    if(x > 0):
        print("nu = ", x)
        nuList.append(x)
        #clf = svm.OneClassSVM(nu=0.0001, kernel="rbf", gamma=0.0001)
        clf = svm.OneClassSVM(nu=x)
        clf.fit(values)
        predicted = clf.predict(values)

        counterFirst = 0
        counterSec = 0
        counts= []
        predictedNew = []
        for i in predicted:
            if i == 1: 
                predictedNew.append(0)
                counterFirst = counterFirst + 1
            else:
                predictedNew.append(1)
                counterSec = counterSec + 1

        cm = confusion_matrix(outlierList, predictedNew)
        print ("num of samples in the first class : ", counterFirst, "   percent: ", counterFirst / len(values))
        print ("num of samples in the secon class : ", counterSec, "     percent: ", counterFirst / len(values))
        print(cm)
        precision = calculatePrecision(cm)
        recall = calculateRecall(cm)
        preList.append(precision)

        print("precision : ", precision)
        print("recall    : " ,recall)
        #plotTheclusteredData(dates, values, predicted, titel= "$OneClassSVM$")
        x = x-0.0001
        print("-----------------")
    else:
        print("nu = 0")
        break
plotTheElbow(nuList ,preList)
# Out:
# nu =  0.002
# num of samples in the first class :  19961    percent:  0.9983994398039314
# num of samples in the secon class :  32      percent:  0.9983994398039314
# [[19961    14]
#  [    0    18]]
# precision :  0.999299123905
# recall    :  1.0
# -----------------
# nu =  0.0019
# num of samples in the first class :  19885    percent:  0.9945981093382684
# num of samples in the secon class :  108      percent:  0.9945981093382684
# [[19885    90]
#  [    0    18]]
# precision :  0.99549436796
# recall    :  1.0
# -----------------
# nu =  0.0018
# num of samples in the first class :  19939    percent:  0.9972990546691342
# num of samples in the secon class :  54      percent:  0.9972990546691342
# [[19939    36]
#  [    0    18]]
# precision :  0.998197747184
# recall    :  1.0
# -----------------
# nu =  0.0017
# num of samples in the first class :  19783    percent:  0.9894963237132997
# num of samples in the secon class :  210      percent:  0.9894963237132997
# [[19783   192]
#  [    0    18]]
# precision :  0.990387984981
# recall    :  1.0
# -----------------
# nu =  0.0015999999999999999
# num of samples in the first class :  19939    percent:  0.9972990546691342
# num of samples in the secon class :  54      percent:  0.9972990546691342
# [[19939    36]
#  [    0    18]]
# precision :  0.998197747184
# recall    :  1.0
# -----------------
# nu =  0.0014999999999999998
# num of samples in the first class :  19930    percent:  0.9968488971139899
# num of samples in the secon class :  63      percent:  0.9968488971139899
# [[19930    45]
#  [    0    18]]
# precision :  0.99774718398
# recall    :  1.0
# -----------------
# nu =  0.0013999999999999998
# num of samples in the first class :  19784    percent:  0.9895463412194268
# num of samples in the secon class :  209      percent:  0.9895463412194268
# [[19784   191]
#  [    0    18]]
# precision :  0.990438047559
# recall    :  1.0
# -----------------
# nu =  0.0012999999999999997
# num of samples in the first class :  19970    percent:  0.9988495973590756
# num of samples in the secon class :  23      percent:  0.9988495973590756
# [[19970     5]
#  [    0    18]]
# precision :  0.999749687109
# recall    :  1.0
# -----------------
# nu =  0.0011999999999999997
# num of samples in the first class :  19966    percent:  0.9986495273345671
# num of samples in the secon class :  27      percent:  0.9986495273345671
# [[19965    10]
#  [    1    17]]
# precision :  0.999499374218
# recall    :  0.999949914855
# -----------------
# nu =  0.0010999999999999996
# num of samples in the first class :  19966    percent:  0.9986495273345671
# num of samples in the secon class :  27      percent:  0.9986495273345671
# [[19964    11]
#  [    2    16]]
# precision :  0.99944931164
# recall    :  0.999899829711
# -----------------
# nu =  0.0009999999999999996
# num of samples in the first class :  19857    percent:  0.9931976191667083
# num of samples in the secon class :  136      percent:  0.9931976191667083
# [[19846   129]
#  [   11     7]]
# precision :  0.993541927409
# recall    :  0.99944603918
# -----------------
# nu =  0.0008999999999999995
# num of samples in the first class :  19973    percent:  0.9989996498774572
# num of samples in the secon class :  20      percent:  0.9989996498774572
# [[19965    10]
#  [    8    10]]
# precision :  0.999499374218
# recall    :  0.99959945927
# -----------------
# nu =  0.0007999999999999995
# num of samples in the first class :  19972    percent:  0.9989496323713299
# num of samples in the secon class :  21      percent:  0.9989496323713299
# [[19965    10]
#  [    7    11]]
# precision :  0.999499374218
# recall    :  0.999649509313
# -----------------
# nu =  0.0006999999999999995
# num of samples in the first class :  19982    percent:  0.9994498074326014
# num of samples in the secon class :  11      percent:  0.9994498074326014
# [[19975     0]
#  [    7    11]]
# precision :  1.0
# recall    :  0.999649684716
# -----------------
# nu =  0.0005999999999999994
# num of samples in the first class :  19982    percent:  0.9994498074326014
# num of samples in the secon class :  11      percent:  0.9994498074326014
# [[19974     1]
#  [    8    10]]
# precision :  0.999949937422
# recall    :  0.999599639676
# -----------------
# nu =  0.0004999999999999994
# num of samples in the first class :  19984    percent:  0.9995498424448557
# num of samples in the secon class :  9      percent:  0.9995498424448557
# [[19975     0]
#  [    9     9]]
# precision :  1.0
# recall    :  0.999549639712
# -----------------
# nu =  0.00039999999999999937
# num of samples in the first class :  19640    percent:  0.982343820337118
# num of samples in the secon class :  353      percent:  0.982343820337118
# [[19627   348]
#  [   13     5]]
# precision :  0.982578222778
# recall    :  0.99933808554
# -----------------
# nu =  0.0002999999999999994
# num of samples in the first class :  19216    percent:  0.9611363977392087
# num of samples in the secon class :  777      percent:  0.9611363977392087
# [[19205   770]
#  [   11     7]]
# precision :  0.961451814768
# recall    :  0.999427560366
# -----------------
# nu =  0.00019999999999999939
# num of samples in the first class :  19763    percent:  0.9884959735907568
# num of samples in the secon class :  230      percent:  0.9884959735907568
# [[19754   221]
#  [    9     9]]
# precision :  0.988936170213
# recall    :  0.999544603552
# -----------------
# nu =  9.999999999999938e-05
# num of samples in the first class :  18297    percent:  0.9151703096083629
# num of samples in the secon class :  1696      percent:  0.9151703096083629
# [[18284  1691]
#  [   13     5]]
# precision :  0.915344180225
# recall    :  0.999289501011
# -----------------
# nu = 0

# %%
values = np.asarray(posDeltaValues).reshape(-1, 1)
dates = np.asarray(deltaDates)
outlierList = outlierPosDelta
datesDisplay = rowDates.copy()
valuesDisplay = rowValues.copy()
del datesDisplay[0]
del valuesDisplay[0]

nuList = []
preList = []

x = 0.002
while(x != 0):
    if(x > 0):
        print("nu = ", x)
        nuList.append(x)
        #clf = svm.OneClassSVM(nu=0.0001, kernel="rbf", gamma=0.0001)
        clf = svm.OneClassSVM(kernel='sigmoid', nu=x)
        clf.fit(values)
        predicted = clf.predict(values)

        counterFirst = 0
        counterSec = 0
        counts= []
        predictedNew = []
        for i in predicted:
            if i == 1: 
                predictedNew.append(0)
                counterFirst = counterFirst + 1
            else:
                predictedNew.append(1)
                counterSec = counterSec + 1

        cm = confusion_matrix(outlierList, predictedNew)
        print ("num of samples in the first class : ", counterFirst, "   percent: ", counterFirst / len(values))
        print ("num of samples in the secon class : ", counterSec, "     percent: ", counterFirst / len(values))
        print(cm)
        precision = calculatePrecision(cm)
        recall = calculateRecall(cm)
        preList.append(precision)

        print("precision : ", precision)
        print("recall    : " ,recall)
        #plotTheclusteredData(dates, values, predicted, titel= "$OneClassSVM$")
        x = x-0.0001
        print("-----------------")
    else:
        print("nu = 0")
        break
plotTheElbow(nuList ,preList)
# Out:
# nu =  0.002
# num of samples in the first class :  18884    percent:  0.9445305857049967
# num of samples in the secon class :  1109      percent:  0.9445305857049967
# [[18866  1109]
#  [   18     0]]
# precision :  0.944480600751
# recall    :  0.999046812116
# -----------------
# nu =  0.0019
# num of samples in the first class :  18852    percent:  0.9429300255089281
# num of samples in the secon class :  1141      percent:  0.9429300255089281
# [[18834  1141]
#  [   18     0]]
# precision :  0.942878598248
# recall    :  0.999045194144
# -----------------
# nu =  0.0018
# num of samples in the first class :  18852    percent:  0.9429300255089281
# num of samples in the secon class :  1141      percent:  0.9429300255089281
# [[18834  1141]
#  [   18     0]]
# precision :  0.942878598248
# recall    :  0.999045194144
# -----------------
# nu =  0.0017
# num of samples in the first class :  19989    percent:  0.9997999299754914
# num of samples in the secon class :  4      percent:  0.9997999299754914
# [[19971     4]
#  [   18     0]]
# precision :  0.999799749687
# recall    :  0.999099504728
# -----------------
# nu =  0.0015999999999999999
# num of samples in the first class :  19989    percent:  0.9997999299754914
# num of samples in the secon class :  4      percent:  0.9997999299754914
# [[19971     4]
#  [   18     0]]
# precision :  0.999799749687
# recall    :  0.999099504728
# -----------------
# nu =  0.0014999999999999998
# num of samples in the first class :  18620    percent:  0.9313259640874306
# num of samples in the secon class :  1373      percent:  0.9313259640874306
# [[18602  1373]
#  [   18     0]]
# precision :  0.9312640801
# recall    :  0.99903329753
# -----------------
# nu =  0.0013999999999999998
# num of samples in the first class :  19979    percent:  0.99929975491422
# num of samples in the secon class :  14      percent:  0.99929975491422
# [[19961    14]
#  [   18     0]]
# precision :  0.999299123905
# recall    :  0.999099054007
# -----------------
# nu =  0.0012999999999999997
# num of samples in the first class :  18603    percent:  0.9304756664832692
# num of samples in the secon class :  1390      percent:  0.9304756664832692
# [[18585  1390]
#  [   18     0]]
# precision :  0.93041301627
# recall    :  0.999032414127
# -----------------
# nu =  0.0011999999999999997
# num of samples in the first class :  18603    percent:  0.9304756664832692
# num of samples in the secon class :  1390      percent:  0.9304756664832692
# [[18585  1390]
#  [   18     0]]
# precision :  0.93041301627
# recall    :  0.999032414127
# -----------------
# nu =  0.0010999999999999996
# num of samples in the first class :  19979    percent:  0.99929975491422
# num of samples in the secon class :  14      percent:  0.99929975491422
# [[19961    14]
#  [   18     0]]
# precision :  0.999299123905
# recall    :  0.999099054007
# -----------------
# nu =  0.0009999999999999996
# num of samples in the first class :  19989    percent:  0.9997999299754914
# num of samples in the secon class :  4      percent:  0.9997999299754914
# [[19971     4]
#  [   18     0]]
# precision :  0.999799749687
# recall    :  0.999099504728
# -----------------
# nu =  0.0008999999999999995
# num of samples in the first class :  19989    percent:  0.9997999299754914
# num of samples in the secon class :  4      percent:  0.9997999299754914
# [[19971     4]
#  [   18     0]]
# precision :  0.999799749687
# recall    :  0.999099504728
# -----------------
# nu =  0.0007999999999999995
# num of samples in the first class :  19967    percent:  0.9986995448406942
# num of samples in the secon class :  26      percent:  0.9986995448406942
# [[19949    26]
#  [   18     0]]
# precision :  0.998698372966
# recall    :  0.999098512546
# -----------------
# nu =  0.0006999999999999995
# num of samples in the first class :  19989    percent:  0.9997999299754914
# num of samples in the secon class :  4      percent:  0.9997999299754914
# [[19971     4]
#  [   18     0]]
# precision :  0.999799749687
# recall    :  0.999099504728
# -----------------
# nu =  0.0005999999999999994
# num of samples in the first class :  19989    percent:  0.9997999299754914
# num of samples in the secon class :  4      percent:  0.9997999299754914
# [[19971     4]
#  [   18     0]]
# precision :  0.999799749687
# recall    :  0.999099504728
# -----------------
# nu =  0.0004999999999999994
# num of samples in the first class :  19989    percent:  0.9997999299754914
# num of samples in the secon class :  4      percent:  0.9997999299754914
# [[19971     4]
#  [   18     0]]
# precision :  0.999799749687
# recall    :  0.999099504728
# -----------------
# nu =  0.00039999999999999937
# num of samples in the first class :  19989    percent:  0.9997999299754914
# num of samples in the secon class :  4      percent:  0.9997999299754914
# [[19971     4]
#  [   18     0]]
# precision :  0.999799749687
# recall    :  0.999099504728
# -----------------
# nu =  0.0002999999999999994
# num of samples in the first class :  19989    percent:  0.9997999299754914
# num of samples in the secon class :  4      percent:  0.9997999299754914
# [[19971     4]
#  [   18     0]]
# precision :  0.999799749687
# recall    :  0.999099504728
# -----------------
# nu =  0.00019999999999999939
# num of samples in the first class :  19991    percent:  0.9998999649877457
# num of samples in the secon class :  2      percent:  0.9998999649877457
# [[19973     2]
#  [   18     0]]
# precision :  0.999899874844
# recall    :  0.999099594818
# -----------------
# nu =  9.999999999999938e-05
# num of samples in the first class :  12524    percent:  0.6264192467363577
# num of samples in the secon class :  7469      percent:  0.6264192467363577
# [[12506  7469]
#  [   18     0]]
# precision :  0.626082603254
# recall    :  0.998562759502
# -----------------
# nu = 0

# %%
# plot the line, the points, and the nearest vectors to the plane
#Z = clf.decision_function(X)
#Z = Z.reshape(X.shape)

#print(Z)

#plt.title("OneClassSVM - posIncreases (classes)")

#plt.set_cmap(pl.cm.Paired)
#plt.contourf(Y, X, Z)

#plt.scatter(Y[:, 0], predicted[:], s=s)
#plt.scatter(Y[:, 0], predicted[:])
